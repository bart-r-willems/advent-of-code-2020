# %% [markdown]
# # Day 4
# [Passport Processing](https://adventofcode.com/2020/day/4)
#
# You arrive at the airport only to realize that you grabbed your North Pole Credentials instead of your passport. While these documents are extremely similar, North Pole Credentials aren't issued by a country and therefore aren't actually valid documentation for travel in most of the world.
#
# It seems like you're not the only one having problems, though; a very long line has formed for the automatic passport scanners, and the delay could upset your travel itinerary

# %%
import re

# %%
passports = {0: {}}
entry_no = 0
with open('input/04_01.txt', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            elements = line.split(' ')
            for element in elements:
                field, value = element.split(':')
                passports[entry_no][field] = value
        else:
            entry_no += 1
            passports[entry_no] = {}
passports = list(passports.values())

# %%
required_fields = {'byr', 'iyr', 'hgt', 'hcl', 'ecl', 'pid', 'eyr'}
valid = 0
for p in passports:
    if len(required_fields.intersection(set(p))) == len(required_fields):
        valid += 1
print(valid)
# Out:
# 256

# %% [markdown]
# ### Check passport values against rules:
#
#     byr (Birth Year) - four digits; at least 1920 and at most 2002.
#     iyr (Issue Year) - four digits; at least 2010 and at most 2020.
#     eyr (Expiration Year) - four digits; at least 2020 and at most 2030.
#     hgt (Height) - a number followed by either cm or in:
#         If cm, the number must be at least 150 and at most 193.
#         If in, the number must be at least 59 and at most 76.
#     hcl (Hair Color) - a # followed by exactly six characters 0-9 or a-f.
#     ecl (Eye Color) - exactly one of: amb blu brn gry grn hzl oth.
#     pid (Passport ID) - a nine-digit number, including leading zeroes.
#     cid (Country ID) - ignored, missing or not.

# %%
def check_byr(value):
    return 1920 <= int(value['byr']) <= 2002

def check_iyr(value):
    return 2010 <= int(value['iyr']) <= 2020

def check_eyr(value):
    return 2020 <= int(value['eyr']) <= 2030

def check_hgt(value):
    if value['hgt'][-2:] in ['cm', 'in']:
        if value['hgt'][-2:] == 'cm':
            return 150 <= int(value['hgt'][:-2]) <= 193
        else:
            return 59 <= int(value['hgt'][:-2]) <= 76
    else:
        return False
    
def check_hcl(value):
    return bool(re.match('#[0-9a-f]{6}?', value['hcl']))

def check_ecl(value):
    return value['ecl'] in ['amb', 'blu', 'brn', 'gry', 'grn', 'hzl', 'oth']

def check_pid(value):
    return bool(re.match('^[0-9]{9}$', value['pid']))

def validate_passport(p, debug=False):
    fn = {'byr': check_byr, 'iyr': check_iyr, 'hgt': check_hgt,
          'hcl': check_hcl, 'ecl': check_ecl, 'pid': check_pid,
          'eyr': check_eyr}
    for fld in fn:
        if fld in p:
            try:
                if not fn[fld](p):
                    if debug: print(f'Invalid {fld}: {p[fld]}')
                    return False
            except Exception as e:
                if debug: print(f'Exception {fld}: [{p[fld]}]')
        else:
            if debug: print(f'Missing {fld}')
            return False
    return True

# %%
print(f'There are {len([p for p in passports if validate_passport(p)])} valid passports.')
# Out:
# There are 198 valid passports.

# %%
print('Valid passports')

for p in passports:
    if validate_passport(p):
        if 'cid' in p:
            print('{byr} {iyr} {hgt:5} {hcl} {ecl} {pid} {eyr} {cid}'.format(**p))
        else:
            print('{byr} {iyr} {hgt:5} {hcl} {ecl} {pid} {eyr} ---'.format(**p))
# Out:
# Valid passports
# 1995 2016 152cm #c0946f oth 543685203 2028 252
# 1989 2013 155cm #733820 grn 728471979 2022 ---
# 1986 2013 171cm #cfa07d grn 214368857 2028 ---
# 1945 2010 167cm #cfa07d brn 429131951 2029 210
# 1966 2015 170cm #888785 amb 893805464 2028 ---
# 1928 2016 170cm #c0946f amb 725010548 2020 ---
# 1999 2016 193cm #888785 hzl 170608679 2026 ---
# 2001 2016 164cm #cfa07d grn 391942873 2024 104
# 1996 2019 166cm #888785 grn 138912840 2025 ---
# 1950 2020 153cm #ceb3a1 gry 493510244 2028 181
# 1988 2018 182cm #866857 hzl 074340974 2023 ---
# 1977 2014 180cm #866857 oth 860745884 2023 ---
# 1992 2012 161cm #b6652a gry 815594641 2026 ---
# 1945 2015 193cm #efcc98 gry 777099878 2021 338
# 1934 2016 162cm #b6652a hzl 742610207 2022 296
# 1965 2010 168cm #fffffd amb 094059049 2024 ---
# 1991 2019 167cm #fffffd grn 243218792 2021 ---
# 2001 2020 156cm #18171d brn 421443124 2021 ---
# 1932 2019 60in  #888785 hzl 359783692 2023 347
# 1999 2011 164cm #7d3b0c hzl 230915137 2020 ---
# 1954 2017 175cm #18171d hzl 966957581 2026 ---
# 1991 2015 192cm #c0946f amb 308053355 2022 146
# 1973 2019 182cm #a97842 amb 244441133 2029 172
# 1985 2017 160cm #623a2f blu 157856689 2030 215
# 1950 2013 172cm #b3f2f0 blu 204254353 2020 169
# 1957 2010 152cm #c0946f blu 325917033 2027 ---
# 1950 2020 166cm #b6652a oth 007352351 2024 ---
# 1955 2010 177cm #602927 grn 585735590 2024 ---
# 1947 2011 170cm #cfa07d blu 404141049 2028 ---
# 1933 2016 167cm #3e845b gry 860077423 2021 ---
# 1946 2014 161cm #602927 brn 822749462 2027 ---
# 1956 2014 173cm #866857 hzl 096026282 2029 ---
# 1957 2019 165cm #3fec29 gry 301205967 2024 276
# 1962 2013 177cm #6b5442 oth 006347857 2021 ---
# 1990 2011 73in  #c0946f oth 415403544 2023 107
# 1964 2015 166cm #c0946f brn 469449137 2029 ---
# 1969 2010 163cm #a97842 blu 570942274 2023 ---
# 1981 2012 183cm #623a2f brn 524675399 2020 ---
# 1979 2017 152cm #fffffd gry 505790864 2026 ---
# 1993 2012 68in  #c0946f grn 933562997 2023 ---
# 1970 2019 166cm #341e13 oth 267705171 2030 ---
# 1972 2015 189cm #341e13 brn 774637408 2026 ---
# 2001 2020 175cm #733820 blu 686996160 2026 ---
# 1987 2020 190cm #c0946f blu 228444464 2030 ---
# 1990 2010 179cm #67067e amb 885359438 2028 ---
# 1945 2019 172cm #866857 brn 708146656 2022 65
# 1920 2011 191cm #efcc98 hzl 010716679 2029 260
# 1951 2012 178cm #733820 blu 264894705 2030 313
# 1926 2013 186cm #866857 amb 790510379 2027 ---
# 1923 2016 191cm #a97842 hzl 535750794 2029 ---
# 1997 2013 170cm #efcc98 oth 792365221 2022 ---
# 1934 2013 184cm #b6652a blu 770238761 2029 177
# 1989 2013 72in  #c0946f hzl 546439165 2024 223
# 1954 2012 189cm #602927 blu 120642045 2026 177
# 1959 2015 156cm #c0946f grn 314624973 2027 349
# 1974 2014 174cm #18171d brn 729198828 2027 ---
# 1966 2014 152cm #602927 gry 848187688 2022 ---
# 1964 2013 168cm #7d3b0c gry 234525998 2021 140
# 1985 2012 72in  #b6652a brn 444365280 2027 ---
# 1994 2011 163cm #a97842 gry 287719484 2023 299
# 1963 2010 176cm #7d3b0c blu 096742425 2030 182
# 1993 2017 185cm #6b5442 gry 366083139 2029 343
# 1960 2010 179cm #18171d amb 878658841 2028 ---
# 1982 2015 187cm #4fe831 blu 537309261 2026 ---
# 1979 2013 163cm #6b5442 brn 924759517 2021 ---
# 1989 2016 190cm #179c55 blu 683651053 2030 ---
# 1994 2016 174cm #b6652a grn 448424292 2020 ---
# 1947 2020 156cm #341e13 hzl 299213638 2023 ---
# 1947 2014 193cm #b6652a hzl 044486467 2025 ---
# 1975 2020 159cm #6b5442 grn 318489576 2029 ---
# 1966 2018 158cm #888785 gry 512971930 2024 100
# 1980 2017 171cm #efcc98 amb 800921581 2030 339
# 1940 2019 169cm #6b5442 hzl 762312913 2029 289
# 1976 2020 172cm #733820 gry 040331561 2022 ---
# 1940 2013 171cm #a6e32a brn 223986941 2027 ---
# 1942 2020 166cm #341e13 amb 435382099 2028 ---
# 1981 2010 155cm #623a2f grn 641326891 2025 298
# 1971 2014 74in  #efcc98 hzl 136003336 2020 96
# 1932 2020 182cm #c0946f oth 367248062 2022 ---
# 1969 2010 189cm #6b5442 grn 022399779 2020 ---
# 1971 2011 153cm #cfa07d brn 819137905 2028 161
# 1972 2011 159cm #a97842 grn 815860793 2027 161
# 1934 2018 183cm #b6652a hzl 732272914 2030 ---
# 1925 2019 191cm #ceb3a1 grn 877388498 2027 236
# 1986 2010 181cm #fffffd brn 801311341 2020 ---
# 1941 2014 181cm #888785 grn 165937945 2028 83
# 1928 2013 76in  #a97842 oth 870072019 2026 127
# 1991 2013 187cm #7d3b0c hzl 008180128 2026 169
# 1949 2010 155cm #18171d amb 586151564 2027 ---
# 1982 2010 167cm #ceb3a1 amb 557737957 2020 235
# 1939 2010 150cm #733820 grn 993218958 2026 ---
# 1961 2017 151cm #623a2f gry 347763159 2024 ---
# 1934 2020 151cm #888785 oth 396545094 2025 ---
# 1943 2019 153cm #733820 gry 081352630 2028 ---
# 1946 2011 161cm #a97842 grn 313741119 2030 ---
# 1968 2018 157cm #18171d gry 742357550 2024 ---
# 1945 2014 190cm #888785 oth 387505919 2028 ---
# 1989 2017 175cm #b6652a gry 499016802 2022 136
# 1967 2016 150cm #ceb3a1 amb 490807331 2026 ---
# 1966 2016 182cm #fffffd grn 061720787 2022 ---
# 1980 2013 156cm #623a2f brn 112283719 2028 ---
# 1956 2013 179cm #6b5442 grn 876589775 2020 ---
# 1942 2015 158cm #888785 amb 546984106 2026 ---
# 1922 2019 172cm #602927 hzl 465052232 2028 ---
# 1951 2019 190cm #c0946f grn 710362693 2023 ---
# 1969 2019 65in  #b6652a brn 466669360 2022 ---
# 1982 2015 166cm #ceb3a1 grn 715680334 2030 283
# 1940 2019 64in  #733820 amb 094541122 2024 ---
# 1993 2019 156cm #cfa07d brn 449484188 2024 ---
# 1997 2020 164cm #623a2f hzl 820731743 2025 ---
# 1953 2014 189cm #602927 oth 949021883 2027 327
# 1982 2015 189cm #733820 grn 796040143 2028 301
# 1988 2013 185cm #cfa07d oth 355177646 2022 169
# 1996 2018 189cm #7d3b0c brn 563150261 2020 84
# 1944 2010 193cm #341e13 oth 486184923 2027 188
# 1969 2019 152cm #888785 gry 430698432 2026 293
# 1954 2017 151cm #602927 gry 051398739 2029 270
# 1987 2012 178cm #cfa07d amb 899973263 2030 ---
# 1964 2016 152cm #c4f777 blu 044307549 2021 80
# 1963 2019 169cm #ceb3a1 brn 330836320 2024 217
# 1976 2018 192cm #602927 oth 452662874 2027 ---
# 1932 2020 160cm #c0946f brn 930667228 2027 310
# 1983 2013 178cm #fffffd gry 955804028 2021 ---
# 2000 2015 189cm #ceb3a1 oth 430243363 2021 284
# 1943 2011 171cm #cfa07d blu 436671537 2021 106
# 1945 2015 169cm #c0946f gry 177443573 2028 ---
# 1995 2010 192cm #fffffd grn 754912745 2021 ---
# 1926 2017 178cm #b99eb9 brn 178633665 2029 141
# 1982 2015 168cm #cfa07d hzl 645675448 2022 ---
# 1980 2010 186cm #c0946f blu 384440210 2027 94
# 1982 2012 192cm #602927 amb 527932745 2027 309
# 1940 2016 166cm #341e13 blu 613386501 2027 132
# 1990 2016 162cm #888785 blu 360563823 2028 287
# 2002 2013 161cm #623a2f gry 535361632 2021 ---
# 1967 2012 67in  #cfa07d hzl 538161833 2024 333
# 1985 2013 164cm #efcc98 gry 021590229 2021 ---
# 1943 2011 165cm #f331b3 hzl 979130395 2021 279
# 1981 2012 161cm #888785 blu 835477382 2025 348
# 1986 2020 178cm #a97842 grn 126915503 2026 ---
# 1944 2020 184cm #a97842 hzl 168775568 2026 67
# 1988 2016 179cm #fffffd oth 379463363 2028 ---
# 1961 2016 172cm #cfa07d amb 320360020 2030 ---
# 1946 2020 173cm #cfa07d oth 066950409 2024 221
# 1966 2019 178cm #602927 gry 583204134 2028 ---
# 1930 2020 192cm #ceb3a1 hzl 285751767 2023 287
# 1990 2015 152cm #18171d hzl 959574669 2024 87
# 1955 2012 162cm #866857 amb 597748286 2023 132
# 1974 2018 188cm #efcc98 oth 212659709 2029 244
# 1957 2012 172cm #ceb3a1 hzl 881271720 2023 ---
# 1967 2017 170cm #888785 amb 198856675 2027 ---
# 1930 2018 175cm #733820 gry 834980363 2026 214
# 1999 2018 169cm #733820 hzl 694719489 2025 328
# 1925 2013 185cm #866857 hzl 806769540 2023 125
# 1994 2010 166cm #733820 hzl 615545523 2027 225
# 1937 2011 185cm #fffffd grn 140250433 2030 ---
# 1924 2010 155cm #ceb3a1 grn 214641920 2022 ---
# 1942 2020 180cm #2fc31f oth 253569416 2027 116
# 1975 2012 193cm #888785 oth 509387921 2022 97
# 1939 2019 190cm #18171d hzl 062827417 2022 ---
# 1944 2018 187cm #a97842 oth 523863237 2026 ---
# 1949 2011 181cm #733820 blu 923996316 2023 110
# 1954 2018 152cm #888785 oth 142200694 2028 ---
# 1935 2014 190cm #efcc98 hzl 945893288 2025 ---
# 1998 2019 188cm #efcc98 grn 252639104 2023 ---
# 1921 2015 193cm #fffffd hzl 653794674 2024 ---
# 1962 2013 180cm #72cace blu 980680460 2030 ---
# 1945 2010 182cm #ceb3a1 amb 597769706 2025 314
# 1939 2015 161cm #888785 blu 761757504 2025 326
# 1981 2017 163cm #888785 gry 330818500 2024 71
# 1949 2010 165cm #602927 amb 727126101 2027 124
# 1966 2014 164cm #866857 grn 184245393 2022 ---
# 1942 2017 180cm #18171d blu 930210027 2027 62
# 1946 2017 171cm #fffffd grn 863414762 2029 95
# 1932 2019 156cm #b6652a grn 715708549 2025 226
# 1981 2019 193cm #696a5c hzl 505158338 2023 57
# 1987 2010 155cm #c0946f grn 431067921 2023 99
# 1966 2013 157cm #733820 amb 957767251 2026 95
# 1969 2013 156cm #a97842 blu 960672229 2020 183
# 1978 2013 192cm #efcc98 grn 222407433 2028 243
# 1923 2016 184cm #a97842 hzl 695935353 2028 327
# 1978 2013 68in  #efcc98 blu 071991002 2021 321
# 1955 2015 165cm #efcc98 grn 137792524 2029 156
# 1949 2014 176cm #cfa07d brn 531868428 2024 ---
# 1938 2016 177cm #efcc98 brn 712202745 2030 137
# 1991 2010 159cm #341e13 grn 357180007 2020 ---
# 1927 2020 151cm #733820 grn 165936826 2023 ---
# 1994 2014 162cm #18171d gry 794227261 2030 ---
# 1981 2017 176cm #7d3b0c gry 973822115 2024 279
# 1946 2013 152cm #fffffd amb 005240023 2029 62
# 1950 2010 184cm #341e13 amb 976217816 2027 ---
# 1987 2011 178cm #602927 grn 684333017 2022 192
# 1954 2015 168cm #602927 hzl 306960973 2029 ---
# 1973 2013 174cm #18171d hzl 922891164 2023 ---
# 1998 2012 189cm #c0946f gry 472066200 2021 299
# 1922 2014 158cm #623a2f oth 594856217 2028 ---
# 1955 2014 187cm #5637d2 grn 862655087 2030 ---
# 1980 2019 176cm #7d3b0c hzl 703908707 2029 346
# 1966 2017 185cm #733820 blu 458522542 2020 120

# %%
print('Invalid passports')           
for p in passports:
    if not validate_passport(p, debug=True):
        print(p)
# Out:
# Invalid passports
# Invalid iyr: 2023
# {'iyr': '2023', 'hcl': 'a58381', 'pid': '#401a29', 'eyr': '1940', 'byr': '1920', 'ecl': 'utc', 'hgt': '183cm'}
# Invalid iyr: 1949
# {'ecl': '#ba3242', 'hgt': '80', 'byr': '1931', 'pid': '550004054', 'iyr': '1949', 'eyr': '1944', 'hcl': 'fb3859'}
# Invalid byr: 2010
# {'pid': '159cm', 'iyr': '1923', 'eyr': '2032', 'hcl': '701107', 'cid': '343', 'ecl': 'gmt', 'byr': '2010', 'hgt': '177cm'}
# Invalid byr: 2017
# {'hgt': '157cm', 'byr': '2017', 'ecl': 'grn', 'iyr': '2012', 'eyr': '2030', 'hcl': '#18171d', 'pid': '173cm'}
# Invalid byr: 2020
# {'pid': '260101979', 'hgt': '187cm', 'eyr': '2033', 'ecl': 'lzr', 'byr': '2020', 'hcl': '1058ce', 'cid': '133', 'iyr': '2012'}
# Missing hgt
# {'hcl': '#7d3b0c', 'pid': '307828343', 'byr': '2001', 'cid': '317', 'iyr': '2013', 'eyr': '2029'}
# Invalid byr: 2014
# {'pid': '472940417', 'eyr': '1960', 'hgt': '181cm', 'hcl': '#c0946f', 'cid': '269', 'byr': '2014', 'iyr': '1956'}
# Invalid byr: 2008
# {'iyr': '1989', 'byr': '2008', 'hgt': '154cm', 'eyr': '2028', 'pid': '280298169', 'cid': '208', 'ecl': 'oth'}
# Invalid ecl: #d72f9b
# {'eyr': '2027', 'ecl': '#d72f9b', 'hgt': '162cm', 'iyr': '2018', 'hcl': '#a97842', 'byr': '1945', 'pid': '131243258'}
# Invalid byr: 2024
# {'hgt': '165', 'eyr': '2030', 'iyr': '2027', 'ecl': '#1a34f1', 'pid': '2894591864', 'byr': '2024', 'hcl': 'z'}
# Missing iyr
# {'byr': '1971', 'ecl': 'oth', 'hgt': '163cm', 'eyr': '2021', 'pid': '040443396'}
# Missing hcl
# {'cid': '74', 'iyr': '2010', 'pid': '014378493', 'hgt': '174cm', 'eyr': '2020', 'ecl': 'grn', 'byr': '1944'}
# Invalid hgt: 73
# {'ecl': 'hzl', 'byr': '1938', 'pid': '235085606', 'cid': '180', 'hcl': '8fb74c', 'eyr': '2021', 'hgt': '73', 'iyr': '2015'}
# Invalid eyr: 1920
# {'hcl': '#733820', 'hgt': '66in', 'eyr': '1920', 'ecl': 'oth', 'byr': '1941', 'pid': '979460474', 'iyr': '2010', 'cid': '247'}
# Invalid iyr: 1951
# {'hcl': '#cfa07d', 'ecl': '#13bd36', 'hgt': '193cm', 'eyr': '2027', 'pid': '181cm', 'byr': '1952', 'iyr': '1951'}
# Invalid byr: 2013
# {'byr': '2013', 'iyr': '2021', 'ecl': 'zzz', 'eyr': '2032', 'hgt': '193in', 'hcl': '#a97842', 'pid': '163cm'}
# Missing ecl
# {'eyr': '2029', 'cid': '140', 'byr': '1984', 'iyr': '2018', 'hgt': '187cm', 'hcl': '#b6652a', 'pid': '910674579'}
# Invalid iyr: 1958
# {'ecl': 'grt', 'byr': '1983', 'hcl': '#cfa07d', 'hgt': '163cm', 'eyr': '1979', 'iyr': '1958', 'pid': '796395720'}
# Invalid byr: 2023
# {'byr': '2023', 'pid': '#eb4c2a', 'iyr': '1939', 'ecl': 'grn', 'hcl': '06d729', 'hgt': '73', 'eyr': '2038'}
# Missing hcl
# {'hgt': '192cm', 'pid': '874141668', 'byr': '1957', 'iyr': '2015', 'ecl': 'gry'}
# Invalid ecl: utc
# {'byr': '1985', 'ecl': 'utc', 'pid': '#ff1cbf', 'iyr': '2018', 'hcl': '#866857', 'hgt': '169cm', 'eyr': '2026', 'cid': '194'}
# Missing ecl
# {'byr': '1978', 'iyr': '2020', 'hgt': '150cm', 'cid': '266', 'eyr': '2026', 'pid': '443912835', 'hcl': '#b6652a'}
# Invalid byr: 2015
# {'pid': '472891001', 'ecl': 'xry', 'hgt': '96', 'hcl': '1b816a', 'iyr': '1954', 'byr': '2015', 'eyr': '2037'}
# Invalid byr: 2027
# {'hgt': '129', 'eyr': '2037', 'cid': '61', 'iyr': '2009', 'byr': '2027', 'hcl': '#c0946f', 'pid': '3569865', 'ecl': '#4e3d72'}
# Invalid hgt: 172in
# {'ecl': 'xry', 'cid': '86', 'hgt': '172in', 'byr': '1972', 'iyr': '2015', 'hcl': '#7d3b0c', 'pid': '833809421', 'eyr': '2030'}
# Invalid byr: 2013
# {'iyr': '2010', 'byr': '2013', 'hgt': '181cm', 'eyr': '2021', 'pid': '072317444', 'ecl': 'oth', 'hcl': '#866857', 'cid': '118'}
# Invalid hgt: 96
# {'pid': '4354408888', 'iyr': '2012', 'hcl': '#b6652a', 'cid': '104', 'hgt': '96', 'eyr': '2020', 'byr': '1933', 'ecl': 'amb'}
# Invalid eyr: 2040
# {'byr': '1932', 'hgt': '170cm', 'iyr': '2014', 'pid': '777844412', 'eyr': '2040', 'hcl': '#cfa07d', 'ecl': 'brn'}
# Missing hcl
# {'cid': '160', 'hgt': '191cm', 'eyr': '2020', 'iyr': '2012', 'ecl': 'brn', 'byr': '1981', 'pid': '077027782'}
# Invalid byr: 2010
# {'byr': '2010', 'cid': '337', 'hcl': 'z', 'pid': '525126586', 'iyr': '2010', 'hgt': '73cm', 'eyr': '2040', 'ecl': 'blu'}
# Missing eyr
# {'hgt': '157cm', 'ecl': 'grn', 'byr': '2000', 'pid': '734707993', 'hcl': '#341e13', 'iyr': '2020'}
# Missing pid
# {'iyr': '2019', 'cid': '172', 'hgt': '152cm', 'eyr': '2022', 'ecl': 'oth', 'hcl': '#602927', 'byr': '1960'}
# Missing hcl
# {'iyr': '2015', 'pid': '472000322', 'eyr': '2021', 'byr': '1977', 'ecl': 'gry', 'hgt': '165cm', 'cid': '270'}
# Missing iyr
# {'eyr': '2027', 'byr': '1956', 'pid': '193087729', 'hcl': '#ceb3a1', 'cid': '213', 'hgt': '193cm', 'ecl': 'oth'}
# Invalid byr: 2021
# {'hcl': 'z', 'pid': '097595072', 'ecl': 'amb', 'iyr': '2015', 'byr': '2021', 'eyr': '2039', 'hgt': '188cm'}
# Invalid byr: 2026
# {'pid': '74823273', 'hcl': '#341e13', 'cid': '166', 'hgt': '182cm', 'byr': '2026', 'iyr': '2027', 'ecl': 'amb', 'eyr': '2032'}
# Invalid byr: 2013
# {'hgt': '72cm', 'iyr': '2015', 'cid': '234', 'byr': '2013', 'ecl': 'brn', 'pid': '9401866358'}
# Invalid hgt: 118
# {'ecl': 'amb', 'hgt': '118', 'byr': '1981', 'iyr': '2019', 'hcl': '#a97842', 'eyr': '2021', 'pid': '270790642'}
# Invalid hgt: 171in
# {'byr': '1925', 'cid': '179', 'ecl': 'hzl', 'pid': '360641953', 'eyr': '2030', 'hgt': '171in', 'iyr': '2015', 'hcl': '#602927'}
# Missing hcl
# {'hgt': '68in', 'ecl': 'blu', 'byr': '1965', 'iyr': '2017', 'pid': '854858050', 'eyr': '2021'}
# Invalid ecl: utc
# {'ecl': 'utc', 'hcl': '#602927', 'pid': '#1408ff', 'byr': '1941', 'cid': '82', 'iyr': '2015', 'hgt': '185cm', 'eyr': '2028'}
# Invalid byr: 2011
# {'iyr': '2011', 'hgt': '155in', 'hcl': '#ceb3a1', 'pid': '118497416', 'eyr': '2029', 'byr': '2011', 'ecl': 'oth'}
# Invalid byr: 2029
# {'hcl': '03a888', 'byr': '2029', 'ecl': '#6f7292', 'eyr': '1969', 'iyr': '2028', 'hgt': '162cm', 'pid': '73551266'}
# Missing iyr
# {'byr': '1971', 'hcl': 'z', 'eyr': '2035', 'pid': '158cm', 'ecl': '#d3ec19'}
# Invalid byr: 2013
# {'hgt': '138', 'byr': '2013', 'eyr': '2040', 'iyr': '2028', 'cid': '197', 'ecl': '#8844fd', 'pid': '8524414485', 'hcl': 'z'}
# Invalid byr: 2016
# {'eyr': '2040', 'hgt': '173in', 'hcl': 'z', 'pid': '#654654', 'byr': '2016', 'iyr': '2022', 'ecl': '#452d22'}
# Missing hcl
# {'iyr': '2012', 'cid': '265', 'eyr': '2021', 'hgt': '192cm', 'byr': '1993', 'ecl': 'brn'}
# Invalid iyr: 2024
# {'iyr': '2024', 'pid': '#a08e69', 'hcl': 'z', 'byr': '1966', 'ecl': '#7b9978', 'eyr': '2035', 'hgt': '69cm'}
# Invalid hgt: 71cm
# {'hcl': '#efcc98', 'pid': '164cm', 'iyr': '2010', 'cid': '194', 'hgt': '71cm', 'byr': '1923', 'eyr': '2026'}
# Invalid hgt: 154in
# {'pid': '42472559', 'hcl': '#6f5763', 'eyr': '2035', 'iyr': '2014', 'hgt': '154in', 'byr': '1939', 'ecl': 'grt', 'cid': '323'}
# Invalid byr: 2022
# {'eyr': '2018', 'iyr': '2029', 'ecl': 'brn', 'byr': '2022', 'pid': '#ff6df1', 'hcl': 'z', 'hgt': '68cm'}
# Missing byr
# {'hgt': '163in', 'eyr': '2022', 'ecl': 'utc', 'hcl': '#ceb3a1', 'iyr': '2028'}
# Invalid byr: 2021
# {'ecl': 'gry', 'pid': '53552934', 'hgt': '193', 'byr': '2021', 'eyr': '2028', 'iyr': '2011', 'cid': '98', 'hcl': '90c63f'}
# Invalid byr: 2011
# {'hcl': '47242b', 'ecl': 'utc', 'hgt': '156', 'pid': '#9a9903', 'eyr': '2030', 'iyr': '1990', 'byr': '2011'}
# Missing iyr
# {'ecl': 'oth', 'eyr': '2030', 'pid': '024655030', 'hgt': '184cm', 'byr': '1969', 'hcl': '#18171d'}
# Invalid byr: 2025
# {'iyr': '1958', 'hgt': '165cm', 'pid': '377677319', 'ecl': 'grt', 'eyr': '2032', 'byr': '2025', 'hcl': 'bbfbe2'}
# Missing byr
# {'eyr': '2027', 'hgt': '183cm', 'ecl': 'brn', 'iyr': '2017', 'hcl': '#341e13', 'pid': '827463598'}
# Invalid hcl: z
# {'pid': '330882171', 'iyr': '2015', 'cid': '211', 'ecl': 'grn', 'byr': '1961', 'eyr': '2021', 'hcl': 'z', 'hgt': '169cm'}
# Invalid byr: 2005
# {'ecl': '#2bc145', 'eyr': '1963', 'iyr': '2030', 'cid': '241', 'hcl': '2fc384', 'hgt': '156in', 'pid': '2899917140', 'byr': '2005'}
# Invalid byr: 2010
# {'hgt': '159cm', 'hcl': 'b4ce6a', 'cid': '319', 'eyr': '2035', 'iyr': '1965', 'ecl': 'oth', 'byr': '2010', 'pid': '158cm'}
# Invalid hcl: 49c7ce
# {'pid': '45938863', 'hcl': '49c7ce', 'cid': '349', 'hgt': '181cm', 'eyr': '2023', 'ecl': 'grn', 'iyr': '2015', 'byr': '1948'}
# Invalid byr: 2024
# {'pid': '293364535', 'byr': '2024', 'hgt': '177cm', 'eyr': '2039', 'iyr': '2020', 'hcl': '#dae928', 'ecl': 'hzl'}
# Missing pid
# {'cid': '140', 'ecl': 'amb', 'eyr': '2022', 'hgt': '181cm', 'hcl': '#efcc98', 'byr': '1943', 'iyr': '2016'}
# Invalid byr: 2019
# {'cid': '71', 'hgt': '151cm', 'pid': '5063555219', 'eyr': '2023', 'ecl': 'hzl', 'byr': '2019', 'hcl': '#7d3b0c', 'iyr': '2023'}
# Invalid byr: 2019
# {'hgt': '157in', 'pid': '#298b06', 'iyr': '2030', 'ecl': '#66a631', 'eyr': '2035', 'hcl': 'z', 'byr': '2019'}
# Invalid iyr: 1943
# {'hgt': '190cm', 'iyr': '1943', 'pid': '644021656', 'hcl': '#6b621c', 'ecl': 'oth', 'eyr': '2021', 'byr': '1923'}
# Missing byr
# {'hcl': '#efcc98', 'eyr': '2029', 'iyr': '2010', 'pid': '980087545', 'ecl': 'brn', 'hgt': '157cm'}
# Invalid pid: 57513658
# {'pid': '57513658', 'iyr': '2011', 'byr': '1993', 'ecl': 'brn', 'eyr': '2027', 'hcl': '#6b5442', 'hgt': '165cm'}
# Invalid hgt: 73cm
# {'byr': '1941', 'ecl': 'gry', 'iyr': '2019', 'eyr': '2026', 'hgt': '73cm', 'hcl': '#602927', 'pid': '352996721'}
# Invalid pid: 178cm
# {'ecl': 'gry', 'byr': '2002', 'iyr': '2017', 'hcl': '#b6652a', 'cid': '261', 'pid': '178cm', 'eyr': '2022', 'hgt': '166cm'}
# Invalid byr: 2027
# {'hcl': 'z', 'pid': '150cm', 'ecl': 'utc', 'iyr': '1981', 'eyr': '2034', 'hgt': '156in', 'cid': '260', 'byr': '2027'}
# Invalid hcl: d596e4
# {'byr': '1987', 'hgt': '66in', 'eyr': '2021', 'pid': '876757018', 'iyr': '2015', 'hcl': 'd596e4', 'ecl': 'hzl'}
# Invalid byr: 2028
# {'iyr': '2025', 'byr': '2028', 'hgt': '165in', 'eyr': '2027', 'pid': '6259332452', 'hcl': '#478251'}
# Invalid byr: 2024
# {'pid': '304792392', 'hcl': '487823', 'eyr': '2020', 'hgt': '70cm', 'byr': '2024', 'iyr': '1953', 'ecl': 'blu'}
# Invalid ecl: utc
# {'ecl': 'utc', 'iyr': '2015', 'byr': '1932', 'hcl': '#623a2f', 'eyr': '2027', 'hgt': '183cm', 'pid': '036300444'}
# Invalid iyr: 1998
# {'hcl': '58aa4a', 'byr': '1930', 'hgt': '193cm', 'iyr': '1998', 'cid': '196', 'ecl': 'brn', 'eyr': '2032'}
# Invalid hgt: 142
# {'pid': '190cm', 'cid': '267', 'iyr': '2015', 'ecl': 'brn', 'hcl': '869252', 'byr': '1935', 'hgt': '142', 'eyr': '2033'}
# Missing byr
# {'cid': '239', 'eyr': '2038', 'ecl': 'lzr', 'hcl': 'z', 'iyr': '1987', 'pid': '4632768239', 'hgt': '162in'}
# Invalid iyr: 2021
# {'pid': '158038227', 'ecl': 'brn', 'byr': '1995', 'eyr': '2028', 'hcl': '#efcc98', 'cid': '252', 'iyr': '2021', 'hgt': '184cm'}
# Invalid byr: 2018
# {'hgt': '190in', 'hcl': 'z', 'eyr': '2029', 'pid': '74228790', 'iyr': '2016', 'byr': '2018', 'ecl': 'brn'}
# Missing hcl
# {'eyr': '2022', 'ecl': 'xry', 'hgt': '154cm', 'pid': '62205162', 'iyr': '2014', 'byr': '1936', 'cid': '61'}
# Invalid pid: #1b34e1
# {'iyr': '2014', 'byr': '1935', 'eyr': '2021', 'cid': '235', 'pid': '#1b34e1', 'hcl': '#89313f', 'hgt': '164cm', 'ecl': 'blu'}
# Invalid pid: 6010745668
# {'pid': '6010745668', 'byr': '1934', 'ecl': 'oth', 'eyr': '2020', 'hgt': '164cm', 'hcl': '#733820', 'iyr': '2016'}
# Invalid byr: 2019
# {'iyr': '1955', 'cid': '108', 'pid': '712137140', 'byr': '2019', 'eyr': '2040', 'hgt': '184cm', 'hcl': '220cfe', 'ecl': '#551592'}
# Missing eyr
# {'pid': '215206381', 'byr': '1928', 'hgt': '163cm', 'hcl': '#b6652a', 'ecl': 'oth', 'iyr': '2011'}
# Invalid ecl: #38a290
# {'cid': '145', 'iyr': '2013', 'ecl': '#38a290', 'eyr': '2034', 'hcl': '#602927', 'hgt': '186cm', 'pid': '517498756', 'byr': '1945'}
# Invalid byr: 2003
# {'pid': '#725759', 'hcl': '#602927', 'iyr': '2013', 'byr': '2003', 'eyr': '2023', 'cid': '100'}
